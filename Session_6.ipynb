# %% [markdown]
# Dictionary in Python Programming

# %% [markdown]
# Dictionary: A dictionary is a built-in data structure in Python that represents a collection of key-value pairs.
# Dictionaries are defined using curly braces {} and consist of keys and their corresponding values.
# Dictionaries are mutable, meaning you can add, remove, or modify key-value pairs after creation. They are
# commonly used for storing and retrieving data based on unique keys.

# %%
my_dict={
    'name' : 'sahil',
    'age' : 21,
    'city' : 'Mumbai'
}

print(my_dict)
# Out:
# {'name': 'sahil', 'age': 21, 'city': 'Mumbai'}

# %%
# Accessing values in a dictionary

print(my_dict['name'])
print(my_dict['city'])
# Out:
# sahil
# Mumbai

# %%
# Adding a new key-value pair to the dictionary
my_dict['country'] = 'India'
print(my_dict)
# Out:
# {'name': 'sahil', 'age': 21, 'city': 'Mumbai', 'country': 'India'}

# %%
# Removing a key-value pair from the dictionary
del my_dict["city"]
print(my_dict)
# Out:
# {'name': 'sahil', 'age': 21, 'country': 'India'}

# %%
# Checking if a key is in the dictionary
print("name" in my_dict) 
print("city" in my_dict)
# Out:
# True
# False

# %% [markdown]
# Methods of Dictionary are as follows :

# %%
# Get the keys of the dictionary

keys=my_dict.keys()
print(keys)
# Out:
# dict_keys(['name', 'age', 'country'])

# %%
# Get the values of the dictionary

values=my_dict.values()
print(values)
# Out:
# dict_values(['sahil', 21, 'India'])

# %%
# Get the key-value pairs of the dictionary

items=my_dict.items()
print(items)
# Out:
# dict_items([('name', 'sahil'), ('age', 21), ('country', 'India')])

# %%
# Clear all key-value pairs from the dictionary

clear=my_dict.clear()
print(my_dict)
# Out:
# {}

# %%
# Copy a dictionary

my_dict_copy=my_dict.copy()
print(my_dict_copy)
# Out:
# {}

# %%
# Update a dictionary with another dictionary

my_dict.update({'name' : 'sahil','age' : 21})
print(my_dict)
# Out:
# {'name': 'sahil', 'age': 21}

# %% [markdown]
# Dictionary Comprehension

# %%
# Create a dictionary using dictionary comprehension

squared_dict={ i : i**2 for i in range(1,6)}
print(squared_dict)
# Out:
# {1: 1, 2: 4, 3: 9, 4: 16, 5: 25}

# %%
# Create a dictionary from two lists using dictionary comprehension

keys = {'a','b','c'}
values = {1,2,3}

two_list={k:v for k,v in zip(keys,values)}
print(two_list)
# Out:
# {'a': 1, 'b': 2, 'c': 3}

# %%
# Create a dictionary with conditional logic using dictionary comprehension

Even_squares={x:x**2 for x in range (1,11) if x % 2 ==0}
print(Even_squares)
# Out:
# {2: 4, 4: 16, 6: 36, 8: 64, 10: 100}

# %%
# Create a dictionary with nested dictionary comprehension

nested_dict={x : {y:y**2 for y in range(1,4)} for x in range (1,4)}
print(nested_dict)
# Out:
# {1: {1: 1, 2: 4, 3: 9}, 2: {1: 1, 2: 4, 3: 9}, 3: {1: 1, 2: 4, 3: 9}}
